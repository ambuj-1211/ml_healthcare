# %%
import pandas as pd 
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# %%
df = pd.read_csv("preprocessed_data_frame.csv")

# %%
df.head(20)
# Out:
#     Unnamed: 0  uniqueID               drugName                condition  \
# 0            0    163740            Mirtazapine               Depression
# 1            1     39293               Contrave              Weight Loss
# 2            2     97768        Cyclafem 1 / 35            Birth Control
# 3            3    215892                 Copper            Birth Control
# 4            4     71428                 Levora            Birth Control
# 5            5     31947             Miconazole  Vaginal Yeast Infection
# 6            6      4907                 Belviq              Weight Loss
# 7            7     97013                 Ambien                 Insomnia
# 8            8    151674                Chantix        Smoking Cessation
# 9            9     33173  Microgestin Fe 1 / 20                     Acne
# 10          10     30401               Klonopin          Bipolar Disorde
# 11          11    231397              Trazodone                 Insomnia
# ...

# %%
df.info(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31683 entries, 0 to 31682
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   31683 non-null  int64
#  1   uniqueID     31683 non-null  int64
#  2   drugName     31683 non-null  object
#  3   condition    31683 non-null  object
#  4   review       31683 non-null  object
#  5   rating       31683 non-null  int64
#  6   date         31683 non-null  object
#  7   usefulCount  31683 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 1.9+ MB

# %%
df.count()
# Out:
# Unnamed: 0     31683
# uniqueID       31683
# drugName       31683
# condition      31683
# review         31683
# rating         31683
# date           31683
# usefulCount    31683
# dtype: int64

# %%
type(df['review'][0])
# Out:
# str

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['condition'] = label_encoder.fit_transform(df['condition'])
df['condition'].unique()
# Out:
# array([ 8, 18,  6, 17, 12, 16,  2,  5,  7,  9, 15, 10,  3,  0, 14, 11, 19,
#         1,  4, 13])

# %%
df.head()
# Out:
#    Unnamed: 0  uniqueID         drugName  condition  \
# 0           0    163740      Mirtazapine          8
# 1           1     39293         Contrave         18
# 2           2     97768  Cyclafem 1 / 35          6
# 3           3    215892           Copper          6
# 4           4     71428           Levora          6
#
#                                               review  rating       date  \
# 0  tri antidepress year citalopram fluoxetin amit...      10  28-Feb-12
# 1  contrav combin drug use alcohol smoke opioid c...       9   5-Mar-17
# 2  birth control one cycl read review type simila...       9  22-Oct-15
# 3  copper coil month realli excit thought take ho...       6   6-Jun-16
# 4  pill almost two year work far get pregnant how...       2  16-Apr-11
#
#    usefulCount
# 0           22
# 1           35
# 2            4
# 3            1
# 4            3

# %%
list(label_encoder.inverse_transform([18]))
# Out:
# ['Weight Loss']

# %%
df.head()
# Out:
#    Unnamed: 0  uniqueID         drugName  condition  \
# 0           0    163740      Mirtazapine          8
# 1           1     39293         Contrave         18
# 2           2     97768  Cyclafem 1 / 35          6
# 3           3    215892           Copper          6
# 4           4     71428           Levora          6
#
#                                               review  rating       date  \
# 0  tri antidepress year citalopram fluoxetin amit...      10  28-Feb-12
# 1  contrav combin drug use alcohol smoke opioid c...       9   5-Mar-17
# 2  birth control one cycl read review type simila...       9  22-Oct-15
# 3  copper coil month realli excit thought take ho...       6   6-Jun-16
# 4  pill almost two year work far get pregnant how...       2  16-Apr-11
#
#    usefulCount
# 0           22
# 1           35
# 2            4
# 3            1
# 4            3

# %%
drug_encoder = preprocessing.LabelEncoder()
df['drugName']=drug_encoder.fit_transform(df['drugName'])

# %%
df.head()
# Out:
#    Unnamed: 0  uniqueID  drugName  condition  \
# 0           0    163740       555          8
# 1           1     39293       202         18
# 2           2     97768       207          6
# 3           3    215892       203          6
# 4           4     71428       460          6
#
#                                               review  rating       date  \
# 0  tri antidepress year citalopram fluoxetin amit...      10  28-Feb-12
# 1  contrav combin drug use alcohol smoke opioid c...       9   5-Mar-17
# 2  birth control one cycl read review type simila...       9  22-Oct-15
# 3  copper coil month realli excit thought take ho...       6   6-Jun-16
# 4  pill almost two year work far get pregnant how...       2  16-Apr-11
#
#    usefulCount
# 0           22
# 1           35
# 2            4
# 3            1
# 4            3

# %%
label_encoder.transform(['Bipolar Disorde'])
# Out:
# array([5])

# %%
df.head()
# Out:
#    Unnamed: 0  uniqueID  drugName  condition  \
# 0           0    163740       555          8
# 1           1     39293       202         18
# 2           2     97768       207          6
# 3           3    215892       203          6
# 4           4     71428       460          6
#
#                                               review  rating       date  \
# 0  tri antidepress year citalopram fluoxetin amit...      10  28-Feb-12
# 1  contrav combin drug use alcohol smoke opioid c...       9   5-Mar-17
# 2  birth control one cycl read review type simila...       9  22-Oct-15
# 3  copper coil month realli excit thought take ho...       6   6-Jun-16
# 4  pill almost two year work far get pregnant how...       2  16-Apr-11
#
#    usefulCount
# 0           22
# 1           35
# 2            4
# 3            1
# 4            3

# %%
import pickle
tfidf = pickle.load(open('tfidf_vectorizer.pkl','rb'))
X=tfidf.transform(df['review'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.0.2 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.0.2 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
X
# Out:
# <31683x14757 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1141801 stored elements in Compressed Sparse Row format>
